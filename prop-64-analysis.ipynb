# %%
import pandas as pd

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.5+ KB

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contribs.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
contribs.committee_name.value_counts()
# Out:
# CALIFORNIA CORRECTIONAL PEACE OFFICERS ASSOCIATION TRUTH IN AMERICAN GOVERNMENT FUND; NO ON PROPOSITION 62, YES ON PROPOSITION 66 (NON-PROFIT 501 (C) 5)                                                    28617
# NEWSOM BALLOT MEASURE COMMITTEE; SAFETY FOR ALL, YES ON PROP. 63,                                                                                                                                            5457
# YES ON 62, NO ON 66. REPLACE THE COSTLY, FAILED DEATH PENALTY SYSTEM. SPONSORED BY TAXPAYERS FOR SENTENCING REFORM                                                                                           4105
# SAVE THE BAG BAN, YES ON 67, SPONSORED BY ENVIRONMENT CALIFORNIA                                                                                                                                             3027
# ...

# %%
contribs[contribs.calaccess_committee_id==1371855].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 39595 to 39634
# Data columns (total 13 columns):
# calaccess_committee_id          40 non-null int64
# committee_name                  40 non-null object
# calaccess_filing_id             40 non-null int64
# date_received                   40 non-null object
# contributor_lastname            40 non-null object
# contributor_firstname           31 non-null object
# contributor_city                40 non-null object
# contributor_state               40 non-null object
# contributor_zip                 40 non-null object
# contributor_employer            29 non-null object
# contributor_occupation          31 non-null object
# contributor_is_self_employed    40 non-null bool
# amount                          40 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 4.1+ KB

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 062- DEATH PENALTY. INITIATIVE STATUTE.                                                                                                             7
# ...

# %%
prop = props[props.prop_name=="PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE."]

# %%
prop.calaccess_committee_id.value_counts()
# Out:
# 1371855    1
# 1376077    1
# 1382525    1
# 1385745    1
# 1390962    1
# 1386560    1
# 1382568    1
# 1387789    1
# 1385506    1
# 1343793    1
# 1381808    1
# Name: calaccess_committee_id, dtype: int64

# %%
merged = pd.merge(prop, contribs, on="calaccess_committee_id")

# %%
merged.committee_position.value_counts().reset_index()
# Out:
#      index  committee_position
# 0  SUPPORT                 762
# 1   OPPOSE                  98

# %%
merged.amount.sum()
# Out:
# 35177017.64

# %%
support=merged[merged.committee_position=="SUPPORT"]

# %%
oppose=merged[merged.committee_position=="OPPOSE"]

# %%
support_sum / merged.amount.sum() * 100
# Out:
# 92.88964270479867

# %%
merged[merged.committee_position=="OPPOSE"].sort_values("amount", ascending=False)
# Out:
#     index                                       ocd_prop_id  \
# 0     839  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# 1     312  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# 2     310  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# 3     308  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# 4     840  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# 5     837  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# 6     838  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# 7     287  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# 8     836  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# 9     306  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# 10    267  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# 11    304  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# 12    291  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# 13    835  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# 14    300  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e
# ...

# %%
support[["amount", "committee_name_x"]].sort_values("amount", ascending=False)
# Out:
#         amount                                   committee_name_x
# 142  4000000.0  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...
# 79   2000000.0  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...
# 851  1970000.0       FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))
# 846  1970000.0  DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...
# 852  1403000.0       FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))
# 141  1250000.0  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...
# 850  1000000.0       FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))
# 143  1000000.0  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...
# 845  1000000.0  DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...
# 254  1000000.0                             NEW APPROACH PAC (MPO)
# 253  1000000.0                             NEW APPROACH PAC (MPO)
# 78   1000000.0  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...
# 259  1000000.0  CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...
# ...

# %%
merged.groupby(["contributor_firstname", "contributor_lastname", "committee_position", "contributor_state"]).amount.sum().reset_index().sort_values("amount", ascending=False).head(20)
# Out:
#     contributor_firstname            contributor_lastname committee_position  \
# 484                  SEAN  PARKER AND AFFILIATED ENTITIES            SUPPORT
# 483                  SEAN                          PARKER            SUPPORT
# 108                DANIEL                           LEWIS            SUPPORT
# 282                 JULIE                         SCHAUER             OPPOSE
# 194                 HENRY                   VAN AMERINGEN            SUPPORT
# 406              NICHOLAS                        PRITZKER            SUPPORT
# 422                 PETER                           THIEL            SUPPORT
# 281                 JULIE                         SCHAUER             OPPOSE
# 457                 ROGER                         JENKINS            SUPPORT
# 23                 ANGELA                          HOWARD            SUPPORT
# 323              LAWRENCE                            HESS            SUPPORT
# ...

# %%
merged[merged.contributor_state!="CA"].amount.sum() / merged.amount.sum()
# Out:
# 0.502766460221157
